# %%
import os
import numpy as np
import pandas as pd

# %%
dirs = '/public/workspace/ryrl/FK/TCGA/Counts'
files = os.listdir(dirs)
# files

lst = []
for file in files:
    df = pd.read_csv(f'{dirs}/{file}', sep='\t', header=0, index_col=0)
    meta = pd.DataFrame(df.columns, columns=['Sample']).assign(Cancer=file.split('.')[0])
    lst.append(meta)
df = pd.concat(lst, axis=0)
df.head()
# Out:
#             Sample Cancer
# 0  TCGA-FU-A3HZ-01   CESC
# 1  TCGA-DR-A0ZM-01   CESC
# 2  TCGA-IR-A3LB-01   CESC
# 3  TCGA-DG-A2KJ-01   CESC
# 4  TCGA-C5-A7CM-01   CESC

# %%
len(df['Cancer'].unique())
# Out:
# 26

# %%
df = df.assign(Group=df['Sample'].apply(lambda x: 'Normal' if x.split('-')[3] == '11' else 'Tumor'))
df.head()
# Out:
#             Sample Cancer  Group
# 0  TCGA-FU-A3HZ-01   CESC  Tumor
# 1  TCGA-DR-A0ZM-01   CESC  Tumor
# 2  TCGA-IR-A3LB-01   CESC  Tumor
# 3  TCGA-DG-A2KJ-01   CESC  Tumor
# 4  TCGA-C5-A7CM-01   CESC  Tumor

# %%
df.to_csv(f'{dirs}/../Meta/metaInfo.txt', sep='\t', index=False, header=True)

# %%
dirs = '/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/results'
files = os.listdir(dirs)

lst = []
for file in files:
    df = pd.read_csv(f'{dirs}/{file}', sep='\t', header=0)
    df = df.assign(Cancer=file.split('.')[0])
    lst.append(df)
df = pd.concat(lst, axis=0)
df.head()
# Out:
#         EnsembleID     baseMean  log2FoldChange     lfcSE      stat  \
# 0  ENSG00000000003  3475.476164        0.322229  0.444323  0.725213
# 1  ENSG00000000419  2638.713544        0.385789  0.270429  1.426582
# 2  ENSG00000000457   910.058851        0.295416  0.277999  1.062651
# 3  ENSG00000000460   878.049313        2.483721  0.316278  7.852957
# 4  ENSG00000000938   514.722699       -1.164826  0.591086 -1.970653
#
#          pvalue          padj Cancer
# 0  4.683214e-01  6.408922e-01   CESC
# 1  1.537006e-01  3.104146e-01   CESC
# 2  2.879401e-01  4.696672e-01   CESC
# 3  4.063408e-15  5.223042e-13   CESC
# 4  4.876355e-02  1.417111e-01   CESC

# %%
df = df.assign(Group_=df.apply(
    lambda x: 'Up' if x['log2FoldChange'] > np.log2(1.5) and x['padj'] < .05 else 'Down' if x['log2FoldChange'] < -np.log2(1.5) and x['padj'] < .05 else 'Normal', axis=1))
df.head()
# Out:
#         EnsembleID     baseMean  log2FoldChange     lfcSE      stat  \
# 0  ENSG00000000003  3475.476164        0.322229  0.444323  0.725213
# 1  ENSG00000000419  2638.713544        0.385789  0.270429  1.426582
# 2  ENSG00000000457   910.058851        0.295416  0.277999  1.062651
# 3  ENSG00000000460   878.049313        2.483721  0.316278  7.852957
# 4  ENSG00000000938   514.722699       -1.164826  0.591086 -1.970653
#
#          pvalue          padj Cancer  Group_
# 0  4.683214e-01  6.408922e-01   CESC  Normal
# 1  1.537006e-01  3.104146e-01   CESC  Normal
# 2  2.879401e-01  4.696672e-01   CESC  Normal
# 3  4.063408e-15  5.223042e-13   CESC      Up
# 4  4.876355e-02  1.417111e-01   CESC  Normal

# %%
metaInfo = pd.read_csv(f'{dirs}/../Meta/metaInfo.txt', sep='\t', header=0)
metaInfo['Group'] = metaInfo['Group'].astype('category').cat.set_categories(['Tumor', 'Normal'], ordered=True)
metaInfo.head()
# Out:
#             Sample Cancer  Group
# 0  TCGA-FU-A3HZ-01   CESC  Tumor
# 1  TCGA-DR-A0ZM-01   CESC  Tumor
# 2  TCGA-IR-A3LB-01   CESC  Tumor
# 3  TCGA-DG-A2KJ-01   CESC  Tumor
# 4  TCGA-C5-A7CM-01   CESC  Tumor

# %%
demo = metaInfo.groupby(by=['Cancer', 'Group']).size().reset_index().groupby(by=['Cancer']).agg(list)
demo.rename(columns={0: 'Count'}, inplace=True)
dit = demo.to_dict()
df = df.assign(**{key: df['Cancer'].map(value) for key, value in dit.items()})
df.head()
# Out:
# /tmp/ipykernel_64458/3119728103.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   demo = metaInfo.groupby(by=['Cancer', 'Group']).size().reset_index().groupby(by=['Cancer']).agg(list)
#         EnsembleID     baseMean  log2FoldChange     lfcSE      stat  \
# 0  ENSG00000000003  3475.476164        0.322229  0.444323  0.725213
# 1  ENSG00000000419  2638.713544        0.385789  0.270429  1.426582
# 2  ENSG00000000457   910.058851        0.295416  0.277999  1.062651
# 3  ENSG00000000460   878.049313        2.483721  0.316278  7.852957
# 4  ENSG00000000938   514.722699       -1.164826  0.591086 -1.970653
#
#          pvalue          padj Cancer  Group_            Group     Count
# 0  4.683214e-01  6.408922e-01   CESC  Normal  [Tumor, Normal]  [306, 3]
# 1  1.537006e-01  3.104146e-01   CESC  Normal  [Tumor, Normal]  [306, 3]
# 2  2.879401e-01  4.696672e-01   CESC  Normal  [Tumor, Normal]  [306, 3]
# 3  4.063408e-15  5.223042e-13   CESC      Up  [Tumor, Normal]  [306, 3]
# 4  4.876355e-02  1.417111e-01   CESC  Normal  [Tumor, Normal]  [306, 3]

# %%
df_ = pd.concat([df.iloc[:, :7], df.iloc[:, 8], df.iloc[:, 7], df.iloc[:, 9:]], axis=1)
df_.head()
# Out:
#         EnsembleID     baseMean  log2FoldChange     lfcSE      stat  \
# 0  ENSG00000000003  3475.476164        0.322229  0.444323  0.725213
# 1  ENSG00000000419  2638.713544        0.385789  0.270429  1.426582
# 2  ENSG00000000457   910.058851        0.295416  0.277999  1.062651
# 3  ENSG00000000460   878.049313        2.483721  0.316278  7.852957
# 4  ENSG00000000938   514.722699       -1.164826  0.591086 -1.970653
#
#          pvalue          padj  Group_ Cancer            Group     Count
# 0  4.683214e-01  6.408922e-01  Normal   CESC  [Tumor, Normal]  [306, 3]
# 1  1.537006e-01  3.104146e-01  Normal   CESC  [Tumor, Normal]  [306, 3]
# 2  2.879401e-01  4.696672e-01  Normal   CESC  [Tumor, Normal]  [306, 3]
# 3  4.063408e-15  5.223042e-13      Up   CESC  [Tumor, Normal]  [306, 3]
# 4  4.876355e-02  1.417111e-01  Normal   CESC  [Tumor, Normal]  [306, 3]

# %%
df.shape, df_.shape
# Out:
# ((585623, 11), (585623, 11))

# %%
df_.to_csv('/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/DESeq2Results.txt', sep='\t', index=None, header=True)

# %%
len(df_['Cancer'].unique())
# Out:
# 19

# %%
df.groupby(by=['Cancer', 'Group_']).size()
# Out:
# Cancer  Group_
# BLCA    Down       4250
#         Normal    18349
#         Up         7249
# BRCA    Down       5579
#         Normal    17234
#         Up         8596
# CESC    Down       2518
#         Normal    23624
#         Up         4253
# CHOL    Down       5008
#         Normal    15790
#         Up         8178
# COAD    Down       5791
#         Normal    13780
#         Up         8952
# ESCA    Down       3909
#         Normal    30657
#         Up         4321
# GBM     Down       6598
#         Normal    18044
#         Up         8741
# HNSC    Down       4995
#         Normal    16994
#         Up         7869
# KICH    Down       7532
#         Normal    14609
#         Up         8086
# KIRC    Down       5065
#         Normal    13929
#         Up        13654
# KIRP    Down       4810
#         Normal    16270
#         Up         9304
# LIHC    Down       3199
#         Normal    14661
#         Up         8991
# LUAD    Down       4806
#         Normal    15870
#         Up        10797
# LUSC    Down       6925
#         Normal    13454
#         Up        12262
# PAAD    Down        259
#         Normal    30919
#         Up          305
# PCPG    Down       2691
#         Normal    22032
#         Up         4954
# PRAD    Down       4709
#         Normal    20078
#         Up         6222
# READ    Down       5276
#         Normal    16039
#         Up         7490
# UCEC    Down       5666
#         Normal    14317
#         Up         9163
# dtype: int64

# %%
metaInfo = pd.read_csv('/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/Meta/metaInfo.txt', sep='\t', header=0)
metaInfo.head()
# Out:
#             Sample Cancer  Group
# 0  TCGA-FU-A3HZ-01   CESC  Tumor
# 1  TCGA-DR-A0ZM-01   CESC  Tumor
# 2  TCGA-IR-A3LB-01   CESC  Tumor
# 3  TCGA-DG-A2KJ-01   CESC  Tumor
# 4  TCGA-C5-A7CM-01   CESC  Tumor

# %%
metaSub = metaInfo.query('Cancer == "OV"')  # OV, DLBC, UCS, MESO, UVM, LGG, ACC
metaSub.head()
# Out:
#                Sample Cancer  Group
# 8443  TCGA-13-1507-01     OV  Tumor
# 8444  TCGA-61-1910-01     OV  Tumor
# 8445  TCGA-25-2042-01     OV  Tumor
# 8446  TCGA-24-2298-01     OV  Tumor
# 8447  TCGA-04-1341-01     OV  Tumor

# %%
metaSub['Group'].value_counts()
# Out:
# Group
# Tumor    379
# Name: count, dtype: int64

# %%
metaSub['Sample'].str.split('-').str[3].value_counts()
# Out:
# Sample
# 01    374
# 02      5
# Name: count, dtype: int64

# %%
gtex = pd.read_csv('/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/GTEx/GTEx_Analysis_v10_RNASeQCv2.4.2_gene_reads.gct.gz', sep='\t', header=0, skiprows=2)
gtex.head()
# Out:
#                 Name  Description  GTEX-1117F-0005-SM-HL9SH  \
# 0  ENSG00000223972.5      DDX11L1                         0
# 1  ENSG00000227232.5       WASH7P                        54
# 2  ENSG00000278267.1    MIR6859-1                         0
# 3  ENSG00000243485.5  MIR1302-2HG                         0
# 4  ENSG00000237613.2      FAM138A                         0
#
#    GTEX-1117F-0011-R10b-SM-GI4VE  GTEX-1117F-0011-R11b-SM-GIN8R  \
# 0                              0                              0
# 1                            117                            457
# 2                              0                              0
# 3                              2                              1
# 4                              0                              0
#
#    GTEX-1117F-0011-R2b-SM-GI4VL  GTEX-1117F-0011-R3a-SM-GJ3PJ  \
# 0                             0                             0
# 1                           183                           167
# 2                             0                             0
# 3                             0                             0
# 4                             1                             0
#
#    GTEX-1117F-0011-R4b-SM-GI4VM  GTEX-1117F-0011-R5a-SM-GI4VW  \
# 0                             1                             0
# 1                           223                           202
# 2                             0                             0
# 3                             1                             0
# 4                             0                             0
#
#    GTEX-1117F-0011-R6a-SM-GI4VX  ...  GTEX-ZZPU-1326-SM-5GZWS  \
# 0                             2  ...                        0
# 1                           224  ...                      135
# 2                             0  ...                        0
# 3                             0  ...                        1
# 4                             0  ...                        0
#
#    GTEX-ZZPU-1426-SM-5GZZ6  GTEX-ZZPU-1826-SM-5E43L  GTEX-ZZPU-2126-SM-5EGIU  \
# 0                        0                        0                        0
# 1                       79                       86                       81
# 2                        0                        0                        0
# 3                        0                        2                        2
# 4                        0                        0                        0
#
#    GTEX-ZZPU-2226-SM-5EGIV  GTEX-ZZPU-2326-SM-GOQYU  GTEX-ZZPU-2426-SM-5E44I  \
# 0                        0                        0                        0
# 1                       47                       89                       83
# 2                        0                        0                        0
# 3                        0                        1                        1
# 4                        0                        0                        0
#
#    GTEX-ZZPU-2526-SM-GOQZ3  GTEX-ZZPU-2626-SM-5E45Y  GTEX-ZZPU-2726-SM-5NQ8O
# 0                        1                        1                        1
# 1                      220                       32                       66
# 2                        0                        0                        0
# 3                        0                        0                        0
# 4                        0                        0                        0
#
# [5 rows x 19790 columns]

# %%
gtex = gtex.assign(GeneId=gtex['Name'].str.split('.').str[0])
gtex.set_index('GeneId', inplace=True)
gtex.reset_index(inplace=True)
gtex.head()
# Out:
#             GeneId               Name  Description  GTEX-1117F-0005-SM-HL9SH  \
# 0  ENSG00000223972  ENSG00000223972.5      DDX11L1                         0
# 1  ENSG00000227232  ENSG00000227232.5       WASH7P                        54
# 2  ENSG00000278267  ENSG00000278267.1    MIR6859-1                         0
# 3  ENSG00000243485  ENSG00000243485.5  MIR1302-2HG                         0
# 4  ENSG00000237613  ENSG00000237613.2      FAM138A                         0
#
#    GTEX-1117F-0011-R10b-SM-GI4VE  GTEX-1117F-0011-R11b-SM-GIN8R  \
# 0                              0                              0
# 1                            117                            457
# 2                              0                              0
# 3                              2                              1
# 4                              0                              0
#
#    GTEX-1117F-0011-R2b-SM-GI4VL  GTEX-1117F-0011-R3a-SM-GJ3PJ  \
# 0                             0                             0
# 1                           183                           167
# 2                             0                             0
# 3                             0                             0
# 4                             1                             0
#
#    GTEX-1117F-0011-R4b-SM-GI4VM  GTEX-1117F-0011-R5a-SM-GI4VW  ...  \
# 0                             1                             0  ...
# 1                           223                           202  ...
# 2                             0                             0  ...
# 3                             1                             0  ...
# 4                             0                             0  ...
#
#    GTEX-ZZPU-1326-SM-5GZWS  GTEX-ZZPU-1426-SM-5GZZ6  GTEX-ZZPU-1826-SM-5E43L  \
# 0                        0                        0                        0
# 1                      135                       79                       86
# 2                        0                        0                        0
# 3                        1                        0                        2
# 4                        0                        0                        0
#
#    GTEX-ZZPU-2126-SM-5EGIU  GTEX-ZZPU-2226-SM-5EGIV  GTEX-ZZPU-2326-SM-GOQYU  \
# 0                        0                        0                        0
# 1                       81                       47                       89
# 2                        0                        0                        0
# 3                        2                        0                        1
# 4                        0                        0                        0
#
#    GTEX-ZZPU-2426-SM-5E44I  GTEX-ZZPU-2526-SM-GOQZ3  GTEX-ZZPU-2626-SM-5E45Y  \
# 0                        0                        1                        1
# 1                       83                      220                       32
# 2                        0                        0                        0
# 3                        1                        0                        0
# 4                        0                        0                        0
#
#    GTEX-ZZPU-2726-SM-5NQ8O
# 0                        1
# 1                       66
# 2                        0
# 3                        0
# 4                        0
#
# [5 rows x 19791 columns]

# %%
gene_ = gtex.iloc[:, :3]
gene_ = gene_.groupby(by='GeneId').agg(lambda x: '/'.join(x)).reset_index()
gene_.head()
# Out:
#             GeneId                Name Description
# 0  ENSG00000000003  ENSG00000000003.15      TSPAN6
# 1  ENSG00000000005   ENSG00000000005.6        TNMD
# 2  ENSG00000000419  ENSG00000000419.14        DPM1
# 3  ENSG00000000457  ENSG00000000457.14       SCYL3
# 4  ENSG00000000460  ENSG00000000460.17    C1orf112

# %%
gtex_ = gtex.drop(columns=['Name', 'Description']).groupby(by='GeneId').median().astype(int).reset_index()
gtex_.head()
# Out:
#             GeneId  GTEX-1117F-0005-SM-HL9SH  GTEX-1117F-0011-R10b-SM-GI4VE  \
# 0  ENSG00000000003                        20                           1322
# 1  ENSG00000000005                         0                              4
# 2  ENSG00000000419                        98                           1018
# 3  ENSG00000000457                        59                            370
# 4  ENSG00000000460                        14                             94
#
#    GTEX-1117F-0011-R11b-SM-GIN8R  GTEX-1117F-0011-R2b-SM-GI4VL  \
# 0                            514                          1483
# 1                              2                             6
# 2                           1091                           827
# 3                            580                           244
# 4                            296                           122
#
#    GTEX-1117F-0011-R3a-SM-GJ3PJ  GTEX-1117F-0011-R4b-SM-GI4VM  \
# 0                          1250                          1348
# 1                            31                            11
# 2                           790                           834
# 3                           365                           478
# 4                            79                           213
#
#    GTEX-1117F-0011-R5a-SM-GI4VW  GTEX-1117F-0011-R6a-SM-GI4VX  \
# 0                          2421                          2827
# 1                             2                             3
# 2                          1355                          1520
# 3                           532                           483
# 4                           195                           233
#
#    GTEX-1117F-0011-R7a-SM-H65ZK  ...  GTEX-ZZPU-1326-SM-5GZWS  \
# 0                          2096  ...                     1473
# 1                             2  ...                        8
# 2                          1146  ...                     1076
# 3                           404  ...                     1030
# 4                           128  ...                      260
#
#    GTEX-ZZPU-1426-SM-5GZZ6  GTEX-ZZPU-1826-SM-5E43L  GTEX-ZZPU-2126-SM-5EGIU  \
# 0                     1142                      553                     7515
# 1                        6                        5                       78
# 2                     1281                     1490                     1336
# 3                      700                      756                      922
# 4                      127                      240                      319
#
#    GTEX-ZZPU-2226-SM-5EGIV  GTEX-ZZPU-2326-SM-GOQYU  GTEX-ZZPU-2426-SM-5E44I  \
# 0                     2502                     4114                      574
# 1                        0                       61                        4
# 2                     1069                     1822                     1441
# 3                      661                     1446                      756
# 4                      300                      368                      182
#
#    GTEX-ZZPU-2526-SM-GOQZ3  GTEX-ZZPU-2626-SM-5E45Y  GTEX-ZZPU-2726-SM-5NQ8O
# 0                     1537                      245                     3501
# 1                      504                      302                     1147
# 2                     1752                     1308                     1331
# 3                     1634                      948                     1187
# 4                      332                       98                      381
#
# [5 rows x 19789 columns]

# %%
gtex_.shape
# Out:
# (58988, 19789)

# %%
'GTEX-1117F-0126-SM-LLLJJ' in gtex_.columns.values
# Out:
# False

# %%
demo = pd.read_csv('/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/GTEx/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt', sep='\t', header=0)
demo.head()
# Out:
# /tmp/ipykernel_167787/4128052114.py:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   demo = pd.read_csv('/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/GTEx/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt', sep='\t', header=0)
#                    SAMPID  SMATSSCR SMCENTER SMPTHNTS  SMRIN           SMTS  \
# 0  BMS-X4LF-0126-SM-4JBHL       NaN       B1      NaN    7.5        Thyroid
# 1  BMS-X4LF-0226-SM-4JBJ3       NaN       B1      NaN    6.9   Blood Vessel
# 2  BMS-X4LF-0326-SM-4JBIR       NaN       B1      NaN    7.4         Muscle
# 3  BMS-X4LF-0426-SM-4JBIS       NaN       B1      NaN    7.1           Skin
# 4  BMS-X4LF-0526-SM-4JBHX       NaN       B1      NaN    8.8  Adrenal Gland
#
#                             SMTSD         SMUBRID  SMTSISCH  SMTSPAX  ...  \
# 0                         Thyroid  UBERON:0002046       NaN      NaN  ...
# 1              Artery - Pulmonary             NaN       NaN      NaN  ...
# 2               Muscle - Skeletal  UBERON:0011907       NaN      NaN  ...
# 3  Skin - Sun Exposed (Lower leg)  UBERON:0004264       NaN      NaN  ...
# 4                   Adrenal Gland  UBERON:0002369       NaN      NaN  ...
#
#   SMSHRTRT SMSMRDHQ SMSMRTHQ SMPRERDHQ SMPRERTHQ SMSMGNDT SMPREGNDT SMRDLNMN  \
# 0      NaN      NaN      NaN       NaN       NaN      NaN       NaN      NaN
# 1      NaN      NaN      NaN       NaN       NaN      NaN       NaN      NaN
# 2      NaN      NaN      NaN       NaN       NaN      NaN       NaN      NaN
# 3      NaN      NaN      NaN       NaN       NaN      NaN       NaN      NaN
# 4      NaN      NaN      NaN       NaN       NaN      NaN       NaN      NaN
#
#   SMRDLNMD  SMRDLNSD
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN
#
# [5 rows x 119 columns]

# %%
'GTEX-1117F-0005-SM-HL9SH' in demo['SAMPID'].values
# Out:
# True

# %%
demo = pd.read_excel('/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/GTEx/GTEx_Analysis_v10_Annotations_SampleAttributesDD.xlsx')
demo.head()
# Out:
#      VARNAME                               VARDESC ACCESS  \
# 0     SAMPID      Sample ID, GTEx Public Sample ID   Open
# 1   SMATSSCR                       Autolysis Score   Open
# 2   SMNABTCH       Nucleic Acid Isolation Batch ID   Open
# 3  SMNABTCHT  Type of nucleic acid isolation batch   Open
# 4  SMNABTCHD  Date of nucleic acid isolation batch   Open
#
#                    DOCFILE                    TYPE UNITS            COMMENT1  \
# 0                      NaN                  string   NaN                 NaN
# 1  PRC Case Summary Report  integer, encoded value   NaN           Autolysis
# 2                    LDACC                  string   NaN  Generated at LDACC
# 3                    LDACC                  string   NaN  Generated at LDACC
# 4                    LDACC                  string   NaN  Generated at LDACC
#
#                                             COMMENT2  VALUES Unnamed: 9  ...  \
# 0                                                NaN     NaN        NaN  ...
# 1  The destruction of organism cells or tissues b...  0=None     1=Mild  ...
# 2  Batch when DNA/RNA was isolated and extracted ...     NaN        NaN  ...
# 3          The process by which DNA/RNA was isolated     NaN        NaN  ...
# 4             The date on which DNA/RNA was isolated     NaN        NaN  ...
#
#   Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51 Unnamed: 52 Unnamed: 53  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 54 Unnamed: 55 Unnamed: 56 Unnamed: 57
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 58 columns]

# %%
df = pd.DataFrame(gtex.columns[2:], columns=['Sample'])
df = df.assign(**{'Cancer': 'GTEx', 'Group': 'Normal'})
df.head()
# Out:
#                           Sample Cancer   Group
# 0       GTEX-1117F-0005-SM-HL9SH   GTEx  Normal
# 1  GTEX-1117F-0011-R10b-SM-GI4VE   GTEx  Normal
# 2  GTEX-1117F-0011-R11b-SM-GIN8R   GTEx  Normal
# 3   GTEX-1117F-0011-R2b-SM-GI4VL   GTEx  Normal
# 4   GTEX-1117F-0011-R3a-SM-GJ3PJ   GTEx  Normal

# %%
metaInfo = pd.concat([metaInfo, df], axis=0)
metaInfo.head()
# Out:
#             Sample Cancer  Group
# 0  TCGA-FU-A3HZ-01   CESC  Tumor
# 1  TCGA-DR-A0ZM-01   CESC  Tumor
# 2  TCGA-IR-A3LB-01   CESC  Tumor
# 3  TCGA-DG-A2KJ-01   CESC  Tumor
# 4  TCGA-C5-A7CM-01   CESC  Tumor

# %%
metaInfo.tail()
# Out:
#                         Sample Cancer   Group
# 19783  GTEX-ZZPU-2326-SM-GOQYU   GTEx  Normal
# 19784  GTEX-ZZPU-2426-SM-5E44I   GTEx  Normal
# 19785  GTEX-ZZPU-2526-SM-GOQZ3   GTEx  Normal
# 19786  GTEX-ZZPU-2626-SM-5E45Y   GTEx  Normal
# 19787  GTEX-ZZPU-2726-SM-5NQ8O   GTEx  Normal

# %%
metaInfo.to_csv('/public/workspace/ryrl/projects/classmates/ryrl/Cancers/TCGA/Meta/metaInfo.txt', sep='\t', index=None, header=True)

# %%
genes = gtex.iloc[:, :2]
genes = genes.assign(gene_id = genes.Name.str.split('.').str[0])
genes.head()
# Out:
#                 Name  Description          gene_id
# 0  ENSG00000223972.5      DDX11L1  ENSG00000223972
# 1  ENSG00000227232.5       WASH7P  ENSG00000227232
# 2  ENSG00000278267.1    MIR6859-1  ENSG00000278267
# 3  ENSG00000243485.5  MIR1302-2HG  ENSG00000243485
# 4  ENSG00000237613.2      FAM138A  ENSG00000237613

# %%
genes['gene_id'].duplicated().sum(), genes.Name.duplicated().sum()
# Out:
# (np.int64(45), np.int64(0))

# %%
df_ = pd.read_csv('/public/workspace/ryrl/FK/TCGA/RNA-seq/Counts/ACC.txt', sep='\t', header=0, index_col=None)
df_.head()
# Out:
#                Tag  TCGA-OR-A5J5-01  TCGA-OR-A5K4-01  TCGA-OR-A5KU-01  \
# 0  ENSG00000000003             1457             2333             1837
# 1  ENSG00000000005                0                2                1
# 2  ENSG00000000419              406             2439             1679
# 3  ENSG00000000457              305              368              246
# 4  ENSG00000000460               75              177               87
#
#    TCGA-OR-A5JK-01  TCGA-OR-A5J8-01  TCGA-OR-A5KW-01  TCGA-OR-A5L9-01  \
# 0             1358             1728             2527              220
# 1                4                3                3                0
# 2             1381             2208             1193               86
# 3              409              536              371               52
# 4              120              417              123               13
#
#    TCGA-OR-A5KY-01  TCGA-OR-A5J3-01  ...  TCGA-OR-A5LM-01  TCGA-PK-A5HB-01  \
# 0             1037             3543  ...             1386             2732
# 1                4                1  ...                0                6
# 2             2317             1050  ...             1759             3179
# 3              429              395  ...              298              673
# 4              343               98  ...               49              500
#
#    TCGA-OR-A5L3-01  TCGA-OR-A5LS-01  TCGA-OR-A5LL-01  TCGA-OR-A5L5-01  \
# 0              714             1954              505             3823
# 1                3               23                0                3
# 2              674             1541             1263             2923
# 3              271              689              419              613
# 4               35              124               95              176
#
#    TCGA-OR-A5K3-01  TCGA-OR-A5JL-01  TCGA-OR-A5JC-01  TCGA-OR-A5JT-01
# 0             1419             3474             1798             2452
# 1                3               12                2               20
# 2             1067             1642             2215             2604
# 3              114              598              236              485
# 4               43               95              107              205
#
# [5 rows x 80 columns]

# %%
gene_ = df_.iloc[:, [0, 0]]
gene_.columns = ['gene_id', 'gene_name']
gene_.head()
# Out:
#            gene_id        gene_name
# 0  ENSG00000000003  ENSG00000000003
# 1  ENSG00000000005  ENSG00000000005
# 2  ENSG00000000419  ENSG00000000419
# 3  ENSG00000000457  ENSG00000000457
# 4  ENSG00000000460  ENSG00000000460

# %%
gene_['gene_id'].duplicated().sum()
# Out:
# np.int64(0)
